# %% [markdown]
# # Requirements

# %%
import json
import numpy as np
import re
import pandas as pd
import geopandas as gpd
import nltk
pd.options.display.max_columns = 1000 # to see all columns
import warnings
warnings.filterwarnings('ignore')
import sddk

# %% [markdown]
# # Loading datasets

# %%
EDHCSg = sddk.read_file("https://sciencedata.dk/public/a9237c5ea642d4714bcdefb03f70a1f4/EDHCSg.geojson", "gdf")
# Out:
# reading a publicly shared file

# %%
EDHCS.head(5)
# Out:
#          EDCS-ID                                     publication  province  \
# 0  EDCS-71300269                                  AE 2014, 01203    Achaia
# 1  EDCS-21200140  CIL 03, 00079 = CIL 03, 14147,6 = IDakke 00028  Aegyptus
# 2  EDCS-21200142   CIL 03, 00081 = CIL 03, 13584 = IDakke 00064a  Aegyptus
# 3  EDCS-52100002                                    IDakke 00064  Aegyptus
# 4  EDCS-44500113                                    IDakke 00100  Aegyptus
#
#   province_list                                              place  \
# 0        Achaia         Mavrommati / Mavromati / Messini / Messene
# 1      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 2      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 3      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 4      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
#
#                                           place_list end_yr_list notes_dating  \
# 0  ['Mavrommati', 'Mavromati', 'Messini', 'Messene']          96
# 1  ['Ad-Dakka', 'El-Dakka', 'Dakke', 'Pselqet', '...         109
# 2  ['Ad-Dakka', 'El-Dakka', 'Dakke', 'Pselqet', '...         109
# 3  ['Ad-Dakka', 'El-Dakka', 'Dakke', 'Pselqet', '...         109
# 4  ['Ad-Dakka', 'El-Dakka', 'Dakke', 'Pselqet', '...         117
#
#                                          status_list  \
# 0  ['sigilla impressa', 'tituli fabricationis', '...
# 1  ['milites', 'tituli fabricationis', 'tituli sa...
# 2                                                 {}
# 3                                tituli possessionis
# 4  ['Augusti/Augustae', 'milites', 'ordo equester...
#
#                                  inscr_type  \
# 0                      tituli fabricationis
# 1  ['tituli fabricationis', 'tituli sacri']
# 2                                        {}
# 3                       tituli possessionis
# 4                              tituli sacri
#
#                                      status_notation     inscr_process  \
# 0                                               viri  sigilla impressa
# 1                 ['milites', 'tria nomina', 'viri']                {}
# 2                                                 {}                {}
# 3                                                 {}                {}
# 4  ['Augusti/Augustae', 'milites', 'ordo equester...                {}
#
#   notes_references notes_comments  \
# 0
# 1
# 2
# 3
# 4
#
#                                          inscription  \
# 0                                      De Rasticanis
# 1  Deo Magno Mercurio / adoravit vexillu / leg(io...
# 2                            Anno / XII [Tr]ai/a[ni]
# 3                                   Anno XX [Tra]ani
# 4  Pro salute Imp(eratoris) Nervae Traiani Caesar...
#
#                           inscription_stripped_final  \
# 0                                      De Rasticanis
# 1  Deo Magno Mercurio / adoravit vexillu / leg(io...
# 2                            Anno / XII [Tr]ai/a[ni]
# 3                                   Anno XX [Tra]ani
# 4  Pro salute Imp(eratoris) Nervae Traiani Caesar...
#
#                                                Links  dating from dating to  \
# 0                                               None         69.0        96
# 1  http://db.edcs.eu/epigr/partner.php?s_language...        109.0       109
# 2                                               None        109.0       109
# 3                                               None        109.0       109
# 4                                               None        103.0       117
#
#                                               status   Latitude  Longitude  \
# 0       sigilla impressa; tituli fabricationis; viri  37.179412  21.924179
# 1  milites; tituli fabricationis; tituli sacri; t...  23.200000  32.750000
# 2                                               None  23.200000  32.750000
# 3                                tituli possessionis  23.200000  32.750000
# 4  Augusti/Augustae; milites; ordo equester; titu...  23.200000  32.750000
#
#   photo       Material Comment EDH-ID language_EDCS  \
# 0  None  opus figlinae    None   None          None
# 1  None           None    None   None          None
# 2  None           None    None   None          None
# 3  None           None    None   None          None
# 4  None           None    None   None          None
#
#                    clean_text_interpretive_word_EDCS responsible_individual  \
# 0                                      De Rasticanis                   None
# 1  Deo Magno Mercurio adoravit vexillu legionis I...                   None
# 2                                   Anno XII Traiani                   None
# 3                                     Anno XX Traani                   None
# 4  Pro salute Imperatoris Nervae Traiani Caesaris...                   None
#
#   type_of_inscription letter_size literature work_status height  \
# 0                None        None       None        None   None
# 1                None        None       None        None   None
# 2                None        None       None        None   None
# 3                None        None       None        None   None
# 4                None        None       None        None   None
#
#   diplomatic_text people depth material type_of_monument province_label width  \
# 0            None   None  None     None             None           None  None
# 1            None   None  None     None             None           None  None
# 2            None   None  None     None             None           None  None
# 3            None   None  None     None             None           None  None
# 4            None   None  None     None             None           None  None
#
#   transcription country   uri findspot_ancient last_update modern_region  \
# 0          None    None  None             None        None          None
# 1          None    None  None             None        None          None
# 2          None    None  None             None        None          None
# 3          None    None  None             None        None          None
# 4          None    None  None             None        None          None
#
#   findspot_modern edh_geography_uri commentary trismegistos_uri  \
# 0            None              None       None             None
# 1            None              None       None             None
# 2            None              None       None             None
# 3            None              None       None             None
# 4            None              None       None             None
#
#   external_image_uris fotos idno_tm placenames_refs text_edition  \
# 0                None  None    None            None         None
# 1                None  None    None            None         None
# 2                None  None    None            None         None
# 3                None  None    None            None         None
# 4                None  None    None            None         None
#
#   origdate_text layout_execution layout_execution_text  support_objecttype  \
# 0          None             None                  None                 NaN
# 1          None             None                  None                 NaN
# 2          None             None                  None                 NaN
# 3          None             None                  None                 NaN
# 4          None             None                  None                 NaN
#
#   support_objecttype_text support_material support_material_text  \
# 0                    None             None                  None
# 1                    None             None                  None
# 2                    None             None                  None
# 3                    None             None                  None
# 4                    None             None                  None
#
#    support_decoration keywords_term keywords_term_text  \
# 0                 NaN          None               None
# 1                 NaN          None               None
# 2                 NaN          None               None
# 3                 NaN          None               None
# 4                 NaN          None               None
#
#   type_of_inscription_clean type_of_inscription_certainty  height_cm  \
# 0                      None                          None        NaN
# 1                      None                          None        NaN
# 2                      None                          None        NaN
# 3                      None                          None        NaN
# 4                      None                          None        NaN
#
#    width_cm  depth_cm material_clean type_of_monument_clean  \
# 0       NaN       NaN           None                   None
# 1       NaN       NaN           None                   None
# 2       NaN       NaN           None                   None
# 3       NaN       NaN           None                   None
# 4       NaN       NaN           None                   None
#
#   type_of_monument_certainty province_label_clean province_label_certainty  \
# 0                       None                 None                     None
# 1                       None                 None                     None
# 2                       None                 None                     None
# 3                       None                 None                     None
# 4                       None                 None                     None
#
#   country_clean country_certainty findspot_ancient_clean  \
# 0          None              None                   None
# 1          None              None                   None
# 2          None              None                   None
# 3          None              None                   None
# 4          None              None                   None
#
#   findspot_ancient_certainty modern_region_clean modern_region_certainty  \
# 0                       None                None                    None
# 1                       None                None                    None
# 2                       None                None                    None
# 3                       None                None                    None
# 4                       None                None                    None
#
#   findspot_modern_clean findspot_modern_certainty findspot_clean  \
# 0                  None                      None           None
# 1                  None                      None           None
# 2                  None                      None           None
# 3                  None                      None           None
# 4                  None                      None           None
#
#   findspot_certainty origdate_text_clean clean_text_conservative  \
# 0               None                None                    None
# 1               None                None                    None
# 2               None                None                    None
# 3               None                None                    None
# 4               None                None                    None
#
#   clean_text_interpretive_sentence findspot year_of_find present_location  \
# 0                             None     None         None             None
# 1                             None     None         None             None
# 2                             None     None         None             None
# 3                             None     None         None             None
# 4                             None     None         None             None
#
#   religion geography social_economic_legal_history military  not_after  \
# 0     None      None                          None     None       96.0
# 1     None      None                          None     None      109.0
# 2     None      None                          None     None      109.0
# 3     None      None                          None     None      109.0
# 4     None      None                          None     None      117.0
#
#   language  not_before                   coordinates  \
# 0    Latin        69.0  ['21.9241791', '37.1794122']
# 1    Latin       109.0    ['32.750000', '23.200000']
# 2    Latin       109.0    ['32.750000', '23.200000']
# 3    Latin       109.0    ['32.750000', '23.200000']
# 4    Latin       103.0    ['32.750000', '23.200000']
#
#                         clean_text_interpretive_word urban_context  \
# 0                                      De Rasticanis           big
# 1  Deo Magno Mercurio adoravit vexillu legionis I...          rest
# 2                                   Anno XII Traiani          rest
# 3                                     Anno XX Traani          rest
# 4  Pro salute Imperatoris Nervae Traiani Caesaris...          rest
#
#    within_rome nearest_city city_id_hanson  city_pop_est  \
# 0        False      Messene             59       22337.0
# 1        False  Elephantine            126       33806.0
# 2        False  Elephantine            126       33806.0
# 3        False  Elephantine            126       33806.0
# 4        False  Elephantine            126       33806.0
#
#             city_geometry nearest_city_type  nearest_city_dist  \
# 0  [22.008029, 37.051363]            middle           0.153060
# 1  [32.933333, 24.083333]               big           0.902158
# 2  [32.933333, 24.083333]               big           0.902158
# 3  [32.933333, 24.083333]               big           0.902158
# 4  [32.933333, 24.083333]               big           0.902158
#
#                     geometry occups  occups_N organizations  organizations_N
# 0  POINT (21.92418 37.17941)     []         0            []                0
# 1  POINT (32.75000 23.20000)     []         0            []                0
# 2  POINT (32.75000 23.20000)     []         0            []                0
# 3  POINT (32.75000 23.20000)     []         0            []                0
# 4  POINT (32.75000 23.20000)     []         0            []                0

# %%
print(EDHCS.columns)
# Out:
# Index(['EDCS-ID', 'publication', 'province', 'province_list', 'place',
#        'place_list', 'end_yr_list', 'notes_dating', 'status_list',
#        'inscr_type',
#        ...
#        'city_id_hanson', 'city_pop_est', 'city_geometry', 'nearest_city_type',
#        'nearest_city_dist', 'geometry', 'occups', 'occups_N', 'organizations',
#        'organizations_N'],
#       dtype='object', length=114)

# %% [markdown]
# # Function to extract occupations

# %%
def extract_occup(inscription_text):
    occups_found = []
    if not isinstance(inscription_text, str): # if not valid string
        inscription_text = ""
    for occup in occups_declined_dict.keys():
        for occup_morph in occups_declined_dict[occup]:
            try:
                if occup_morph in inscription_text: # first check it this way, otherwise skip
                    occup_morph_N = len(re.findall("(\W|^)" + occup_morph + "(\W|$)", inscription_text))
                    occups_found.extend([occup] * occup_morph_N)
                    inscription_text = inscription_text.replace(occup_morph, "")
            except: pass
    return occups_found

# %% [markdown]
# # Occupations - extraction

# %%
# read declined occupations
with open("../data/occups_declined_dict.json", "r") as fp:
    occups_declined_dict = json.load(fp)

# %%
# check that our occupations are properly arranged (from the longest...)
list(occups_declined_dict.keys())[:20]
# Out:
# ['exactor auri argenti et aeris',
#  'inclusor auri et gemmarum',
#  'tesserarius lignarius',
#  'refector pectinarius',
#  'instructor parietum',
#  'tribor argentarius',
#  'carrocarpentarius',
#  'dactilidiogliphus',
#  'manceps salinarum',
#  'manceps thermarum',
#  'aequator monetae',
#  'conchyliolegulus',
#  'orchestopolarius',
#  'rhypararographus',
#  'calciamentarius',
#  'chorographarius',
#  'diffusor oleari',
#  'domnicomontanus',
#  'faber tignuarii',
#  'medicamentarius']

# %%
# %%time
EDHCS["occups"] = EDHCS["clean_text_interpretive_word"].apply(extract_occup)
# Out:
# CPU times: user 1min 10s, sys: 0 ns, total: 1min 10s
# Wall time: 1min 10s

# %%
EDHCS["occups_N"] = EDHCS["occups"].apply(len)

# %%
EDHCS["occups_N"].sum()
# Out:
# 3840

# %%
EDHCS_occups_list = [el for sublist in EDHCS["occups"].tolist() for el in sublist]
occupations_counts = pd.DataFrame(nltk.FreqDist(EDHCS_occups_list).most_common(), columns=["occupation", "count"])
occupations_counts.head(10)
# Out:
#      occupation  count
# 0         faber    690
# 1       curator    340
# 2       medicus    249
# 3      aerarius    235
# 4    negotiator    130
# 5   centonarius    124
# 6        scriba    108
# 7   vexillarius     75
# 8        mensor     73
# 9  dendrophorus     61

# %%
# load the occupation list
occupations_df = pd.read_csv("../data/occupations_list_hisco.csv")
occupations_df.head(5)
# Out:
#           Term gen_sg Vocab_nom_sg             Source  HISCO_majorgroup  \
# 0    abetarius      i          NaN  Petrikovits 1981a               8.0
# 1   abietarius      i          NaN  Petrikovits 1981a               8.0
# 2     acceptor   oris     acceptor    Waltzing - Rome               3.0
# 3  accomodator   oris          NaN  Petrikovits 1981a               9.0
# 4      aceptor   oris          NaN  Petrikovits 1981a               3.0
#
#    HISCO_minorgroup  Harris_Category  Subcategory  \
# 0              81.0         Building  Wood worker
# 1              81.0         Building  Wood worker
# 2              31.0          Finance          NaN
# 3              99.0  Unclear meaning          NaN
# 4              31.0          Finance          NaN
#
#                    Translation_eng
# 0            a joiner, wood worker
# 1            a joiner, wood worker
# 2  collector, gold quality checker
# 3             uncertain, craftsman
# 4  collector, gold quality checker

# %%
def get_int(x):
    try: return str(int(x))
    except: return ""
occupations_df["HISCO_majorgroup"] = occupations_df["HISCO_majorgroup"].apply(get_int)
occupations_df["HISCO_minorgroup"] = occupations_df["HISCO_minorgroup"].apply(get_int)

# %%
occupations_df.head(5)
# Out:
#           Term gen_sg Vocab_nom_sg             Source HISCO_majorgroup  \
# 0    abetarius      i          NaN  Petrikovits 1981a                8
# 1   abietarius      i          NaN  Petrikovits 1981a                8
# 2     acceptor   oris     acceptor    Waltzing - Rome                3
# 3  accomodator   oris          NaN  Petrikovits 1981a                9
# 4      aceptor   oris          NaN  Petrikovits 1981a                3
#
#   HISCO_minorgroup  Harris_Category  Subcategory  \
# 0               81         Building  Wood worker
# 1               81         Building  Wood worker
# 2               31          Finance          NaN
# 3               99  Unclear meaning          NaN
# 4               31          Finance          NaN
#
#                    Translation_eng
# 0            a joiner, wood worker
# 1            a joiner, wood worker
# 2  collector, gold quality checker
# 3             uncertain, craftsman
# 4  collector, gold quality checker

# %%
occupation_dict = {}
keys = ["Harris_Category", "Source", "HISCO_majorgroup", "Subcategory", "HISCO_minorgroup", "Translation_eng"]
for n in range(len(occupations_df)):
    occupation_dict[occupations_df.iloc[n]["Term"]] = dict([(key, occupations_df.iloc[n][key]) for key in keys])

# %%
occupation_dict
# Out:
# {'abetarius': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': 'Wood worker',
#   'HISCO_minorgroup': '81',
#   'Translation_eng': 'a joiner, wood worker'},
#  'abietarius': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': 'Wood worker',
#   'HISCO_minorgroup': '81',
#   'Translation_eng': 'a joiner, wood worker'},
#  'acceptor': {'Harris_Category': 'Finance',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '3',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '31',
#   'Translation_eng': 'collector, gold quality checker'},
#  'accomodator': {'Harris_Category': 'Unclear meaning',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '99',
#   'Translation_eng': 'uncertain, craftsman'},
#  'aceptor': {'Harris_Category': 'Finance',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '3',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '31',
#   'Translation_eng': 'collector, gold quality checker'},
#  'aciscularius': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'craftsman, working with small axe'},
#  'acuarius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'manufacturer or seller of needles'},
#  'acuclarius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'manufacturer or seller of needles'},
#  'acucularius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981b',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'manufacturer or seller of a small pin for a head-dress'},
#  'acutarius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'manufacturer or seller of a pointy objects'},
#  'acutiator': {'Harris_Category': 'Food-Production',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '6',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '61',
#   'Translation_eng': 'grindworker, grindmaster'},
#  'adulterator': {'Harris_Category': 'Finance',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '3',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '39',
#   'Translation_eng': 'coin counterfeiter'},
#  'aedifex': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '0',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '2',
#   'Translation_eng': 'builder'},
#  'aedificator': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '0',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '2',
#   'Translation_eng': 'builder, architect'},
#  'aeneator': {'Harris_Category': 'Performing Arts',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '1',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '17',
#   'Translation_eng': 'musician, one who blows a horn in war\n'},
#  'aequator monetae': {'Harris_Category': 'Finance',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '3',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '31',
#   'Translation_eng': 'one who, in the coining of money, examines the equality of its weight, an assizer'},
#  'aerarius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'metal worker'},
#  'agricola': {'Harris_Category': 'Food-Production',
#   'Source': "Petra's addition",
#   'HISCO_majorgroup': '6',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '62',
#   'Translation_eng': 'a husbandman, agriculturist, ploughman, farmer, peasant'},
#  'agrimensor': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '0',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '2',
#   'Translation_eng': 'a landsurveyor'},
#  'agrimesor': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '0',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '2',
#   'Translation_eng': 'a landsurveyor'},
#  'albarius': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'worker in stucco, a plasterer'},
#  'alicarius': {'Harris_Category': 'Food-Production',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '6',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '61',
#   'Translation_eng': 'one who grinds spelt'},
#  'aluminarius': {'Harris_Category': 'Fuel / Raw material',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '71',
#   'Translation_eng': 'worker or seller or alum (mineral)'},
#  'ampullarius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '89',
#   'Translation_eng': 'manufacturer of ampullae (small vessels from glass and leather)'},
#  'anabolicarius': {'Harris_Category': 'Transport',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Maritime/water transport',
#   'HISCO_minorgroup': '98',
#   'Translation_eng': 'one day sailor'},
#  'anaglitarius': {'Harris_Category': 'Plastic Arts',
#   'Source': 'Petrikovits 1981b',
#   'HISCO_majorgroup': '1',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '16',
#   'Translation_eng': 'relief maker, carver'},
#  'anaglypharius': {'Harris_Category': 'Plastic Arts',
#   'Source': 'Petrikovits 1981b',
#   'HISCO_majorgroup': '1',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '16',
#   'Translation_eng': 'relief maker, carver'},
#  'anaglyptarius': {'Harris_Category': 'Plastic Arts',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '1',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '16',
#   'Translation_eng': 'relief maker, carver'},
#  'anellarius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981b',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'ring maker'},
#  'annellarius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'ring maker'},
#  'annonarius': {'Harris_Category': 'Managerial',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '3',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '30',
#   'Translation_eng': 'of or pertaining to provisions'},
#  'anularius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'maker of rings'},
#  'apothecarius': {'Harris_Category': 'Retail',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '4',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '43',
#   'Translation_eng': 'a warehouseman'},
#  'apparator': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '99',
#   'Translation_eng': 'one that prepares'},
#  'applumbator': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '72',
#   'Translation_eng': 'lead worker, solder'},
#  'adplumbator': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '72',
#   'Translation_eng': 'lead worker, solder'},
#  'aquarius': {'Harris_Category': 'Water-Management',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'fountain worker, of water, watery, water carrier'},
#  'aquator': {'Harris_Category': 'Water-Management',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '97',
#   'Translation_eng': 'a water-carrier'},
#  'arcarius': {'Harris_Category': 'Finance',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '3',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '31',
#   'Translation_eng': 'treasurer, a controller of public revenues'},
#  'archimagirus': {'Harris_Category': 'Food-Production',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'chef'},
#  'architecton': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '0',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '2',
#   'Translation_eng': 'a masterbuilder, architect'},
#  'architectus': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '0',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '2',
#   'Translation_eng': 'a master-builder, architect'},
#  'arcuarius': {'Harris_Category': 'Finance',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '3',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '31',
#   'Translation_eng': 'treasurer, a controller of public revenues'},
#  'arcularius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '81',
#   'Translation_eng': 'one that makes little boxes, chests'},
#  'arecarius': {'Harris_Category': 'Transport',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '0',
#   'Subcategory': 'Maritime/water transport',
#   'HISCO_minorgroup': '4',
#   'Translation_eng': 'small boat owner'},
#  'arenarius': {'Harris_Category': 'Performing Arts',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '1',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '17',
#   'Translation_eng': 'harenarius, combatant in the amphitheatre, a gladiator'},
#  'argentarius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'jewellery maker, banker'},
#  'armamentarius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': 'Military',
#   'HISCO_minorgroup': '58',
#   'Translation_eng': 'an arsenal provider, armory keeper'},
#  'armamintarius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': 'Military',
#   'HISCO_minorgroup': '58',
#   'Translation_eng': 'an arsenal provider, armory keeper'},
#  'armariarius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '81',
#   'Translation_eng': 'cabinet maker'},
#  'armilarius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'bracelet maker, armilla - bracelet'},
#  'armillarius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981b',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'bracelet maker'},
#  'aromatarius': {'Harris_Category': 'Retail',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '4',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '43',
#   'Translation_eng': 'seller of perfumes, spices'},
#  'artefex': {'Harris_Category': 'Plastic Arts',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '1',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '16',
#   'Translation_eng': 'One that is master in the liberal arts,an artist, artificer'},
#  'artifex': {'Harris_Category': 'Plastic Arts',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '1',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '16',
#   'Translation_eng': 'One that is master in the liberal arts,an artist, artificer'},
#  'asinarius': {'Harris_Category': 'Transport',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Land transport',
#   'HISCO_minorgroup': '97',
#   'Translation_eng': 'a keeper of asses, an ass-driver'},
#  'assator': {'Harris_Category': 'Food-Production',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'cooker'},
#  'athleta': {'Harris_Category': 'Performing Arts',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '1',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '17',
#   'Translation_eng': 'a wrestler, athlete, combatant in public games'},
#  'aulopoios': {'Harris_Category': 'Plastic Arts',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '1',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '16',
#   'Translation_eng': 'maker of aulos, Greek musical instrument'},
#  'aupiciarius': {'Harris_Category': 'Transport',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '98',
#   'Translation_eng': 'uncertain, related to boat'},
#  'aurarius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '71',
#   'Translation_eng': 'gold-mine worker'},
#  'aurator': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'gilder'},
#  'auricaesor': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'manufacturer of sheet gold'},
#  'auricoctor': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '72',
#   'Translation_eng': 'he that melts or refines gold'},
#  'aurifaber': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981b',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'goldsmith'},
#  'aurifex': {'Harris_Category': 'Metal-Working',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'goldsmith'},
#  'aurificus': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'goldworker, goldsmith'},
#  'aurifossor': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '71',
#   'Translation_eng': 'gold digger'},
#  'aurufex': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'goldworker, goldsmith'},
#  'automatarius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '99',
#   'Translation_eng': 'a maker of automata'},
#  'axearius': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '82',
#   'Translation_eng': 'uncertain, board-cutter'},
#  'baiulius': {'Harris_Category': 'Transport',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Land transport',
#   'HISCO_minorgroup': '97',
#   'Translation_eng': 'a porter, carrier'},
#  'ballistarius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '0',
#   'Subcategory': 'Military',
#   'HISCO_minorgroup': '2',
#   'Translation_eng': 'manufacturer of ballistae, an engine for hurling'},
#  'ballistrarius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '0',
#   'Subcategory': 'Military',
#   'HISCO_minorgroup': '2',
#   'Translation_eng': 'manufacturer of ballistae, an engine for hurling'},
#  'baltearius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'a maker or master of sword-belts'},
#  'barbaricarius': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovist 1981b',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '75',
#   'Translation_eng': 'textile worker'},
#  'barbaricas': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '75',
#   'Translation_eng': 'textile worker'},
#  'bastagarius': {'Harris_Category': 'Clothing',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '80',
#   'Translation_eng': 'a baggage-master'},
#  'baxiarius': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': 'Shoe maker',
#   'HISCO_minorgroup': '80',
#   'Translation_eng': 'sandal-maker'},
#  'baxearius': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': 'Shoe maker',
#   'HISCO_minorgroup': '80',
#   'Translation_eng': 'sandal-maker'},
#  'biroigallus': {'Harris_Category': 'Unclear meaning',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '',
#   'Translation_eng': 'uncertain'},
#  'blattiarius': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': 'Colour production',
#   'HISCO_minorgroup': '75',
#   'Translation_eng': 'manufacturer of purpur'},
#  'boarius': {'Harris_Category': 'Food-Production',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '6',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '62',
#   'Translation_eng': 'cattle breader'},
#  'botularius': {'Harris_Category': 'Food-Production',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'manufacturer of sausages'},
#  'bracarius': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '79',
#   'Translation_eng': 'manufacturer of trousers'},
#  'braccarius': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '79',
#   'Translation_eng': 'manufacturer of trousers'},
#  'bractearius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'goldsheet maker, worker'},
#  'bracteator': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'goldsheet maker, worker'},
#  'brattearius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'goldsheet maker, worker'},
#  'brattiarius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'goldsheet maker, worker'},
#  'bucaeda': {'Harris_Category': 'Food-Production',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'beef butcher'},
#  'buccularius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'maker of helmet flaps'},
#  'bucida': {'Harris_Category': 'Food-Production',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'beef butcher'},
#  'budinarius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '81',
#   'Translation_eng': 'reed weaver'},
#  'burrarius': {'Harris_Category': 'Unclear meaning',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '99',
#   'Translation_eng': 'uncertain, unspecified worker'},
#  'bustuarius': {'Harris_Category': 'Death-care sector',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '59',
#   'Translation_eng': 'cremator'},
#  'cabator': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'engraver, maker of hollow spaces'},
#  'cabidarius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'uncertain, cup maker'},
#  'caelator': {'Harris_Category': 'Plastic Arts',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '1',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '16',
#   'Translation_eng': 'relief maker, carver'},
#  'caementarius': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Stone worker',
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'mason'},
#  'caesor': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Stone worker',
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'stone mason'},
#  'calcarensis': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': 'Stone worker',
#   'HISCO_minorgroup': '74',
#   'Translation_eng': 'a limeburner'},
#  'calcariensis': {'Harris_Category': 'Building',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '7',
#   'Subcategory': 'Stone worker',
#   'HISCO_minorgroup': '74',
#   'Translation_eng': 'a limeburner'},
#  'calcarius': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': 'Stone worker',
#   'HISCO_minorgroup': '71',
#   'Translation_eng': 'limestone quarry worker'},
#  'calcearius': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': 'Stone worker',
#   'HISCO_minorgroup': '71',
#   'Translation_eng': 'limestone quarry worker'},
#  'calceator': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': 'Shoe maker',
#   'HISCO_minorgroup': '80',
#   'Translation_eng': 'a shoemaker'},
#  'calceolarius': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': 'Shoe maker',
#   'HISCO_minorgroup': '80',
#   'Translation_eng': 'a shoemaker'},
#  'calciamentarius': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': 'Shoe maker',
#   'HISCO_minorgroup': '80',
#   'Translation_eng': 'a shoemaker'},
#  'calciator': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': 'Shoe maker',
#   'HISCO_minorgroup': '80',
#   'Translation_eng': 'a shoemaker'},
#  'calcis coctor': {'Harris_Category': 'Building',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '7',
#   'Subcategory': 'Stone worker',
#   'HISCO_minorgroup': '74',
#   'Translation_eng': 'limeburner'},
#  'calegarius': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': 'Shoe maker',
#   'HISCO_minorgroup': '80',
#   'Translation_eng': 'a shoemaker'},
#  'caligarius': {'Harris_Category': 'Clothing',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '8',
#   'Subcategory': 'Shoe maker',
#   'HISCO_minorgroup': '80',
#   'Translation_eng': 'a shoemaker'},
#  'camararius': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'vault building worker'},
#  'camarius': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'vault building worker'},
#  'canalicularius': {'Harris_Category': 'Water-Management',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'canal constructor, specialized worker'},
#  'candelabrarius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'manufacturer of candelabra, lamp-stand'},
#  'candidarius': {'Harris_Category': 'Food-Production',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'a baker'},
#  'candidator': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '79',
#   'Translation_eng': 'uncertain, textile washer'},
#  'canephorus': {'Harris_Category': 'Transport',
#   'Source': 'Waltzing',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Land transport',
#   'HISCO_minorgroup': '97',
#   'Translation_eng': 'that bears a basket'},
#  'capidarius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'uncertain, cup maker'},
#  'capistrarius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '80',
#   'Translation_eng': 'a halter-maker'},
#  'caplator': {'Harris_Category': 'Transport',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '97',
#   'Translation_eng': 'oil transporter'},
#  'capsarius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '0',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '6',
#   'Translation_eng': 'healing asssitant, producer of capsae (a repository, box, bookcase)'},
#  'capulator': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'decanter'},
#  'carbonarius': {'Harris_Category': 'Fuel / Raw material',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '71',
#   'Translation_eng': 'coal handler, worker, miner'},
#  'carbonarus': {'Harris_Category': 'Fuel / Raw material',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '71',
#   'Translation_eng': 'coal handler, worker, miner'},
#  'cartharius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '91',
#   'Translation_eng': 'papyrus maker'},
#  'carinarius': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': 'Colour production',
#   'HISCO_minorgroup': '75',
#   'Translation_eng': 'he who colors wax-color, a dyer of yellow'},
#  'caritor': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '75',
#   'Translation_eng': 'wool worker'},
#  'carminator': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '75',
#   'Translation_eng': 'a carder, practitioner of carding, a method of preparing wool for use as a textile'},
#  'carnarius': {'Harris_Category': 'Food-Production',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'butcher, meat worker, of or belonging to flesh'},
#  'carpentarius': {'Harris_Category': 'Transport',
#   'Source': 'Petrikovits 1981b',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Land transport',
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'a wheelwright'},
#  'carrarius': {'Harris_Category': 'Transport',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Land transport',
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'a wheelwright, cart maker'},
#  'carrocarpentarius': {'Harris_Category': 'Transport',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Land transport',
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'a wheelwright'},
#  'cassidarius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'a helmet smith'},
#  'catabolensis': {'Harris_Category': 'Transport',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Land transport',
#   'HISCO_minorgroup': '97',
#   'Translation_eng': 'a class of carriers who transport burdens by means of draught animals, a kind of muleteers'},
#  'caudicarius': {'Harris_Category': 'Transport',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Maritime/water transport',
#   'HISCO_minorgroup': '98',
#   'Translation_eng': 'those who sail on such ships (esp. those who brought the corn from Ostia to Rome)'},
#  'caupo': {'Harris_Category': 'Retail',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '4',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '43',
#   'Translation_eng': 'a petty tradesman, huckster, innkeeper'},
#  'cauponarius': {'Harris_Category': 'Food-Retail',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '51',
#   'Translation_eng': 'tavern keeper'},
#  'cavator': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '82',
#   'Translation_eng': 'engraver, maker of hollow spaces'},
#  'cavidarius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'uncertain, cup maker'},
#  'cellararius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '55',
#   'Translation_eng': 'one who keeps provisions, a steward, butler'},
#  'cellariarius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981b',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '55',
#   'Translation_eng': 'one who keeps provisions, a steward, butler'},
#  'cellaricarius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '55',
#   'Translation_eng': 'one who keeps provisions, a steward, butler'},
#  'cellarius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '55',
#   'Translation_eng': 'one who keeps provisions, a steward, butler'},
#  'cellio': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '55',
#   'Translation_eng': 'one who keeps provisions, a steward, butler'},
#  'cementarius': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Stone worker',
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'mason'},
#  'centonarius': {'Harris_Category': 'Clothing',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '79',
#   'Translation_eng': 'a maker of patchwork, a dealer in rags'},
#  'cerarius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '77',
#   'Translation_eng': 'manufacturer of wax products'},
#  'cerdo': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '94',
#   'Translation_eng': 'a handicraftsman'},
#  'cerearius': {'Harris_Category': 'Unclear meaning',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'uncertain worker, maybe baker'},
#  'ceriolarius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '77',
#   'Translation_eng': 'wax candles manufacturer'},
#  'ceromatita': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '57',
#   'Translation_eng': 'masseur, trainer'},
#  'cervesarius': {'Harris_Category': 'Food-Production',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'beermaker, brewer'},
#  'cesor': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Stone worker',
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'stone mason'},
#  'characteraria': {'Harris_Category': 'Unclear meaning',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '99',
#   'Translation_eng': 'uncertain, marker maker or letter maker'},
#  'chartarius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '91',
#   'Translation_eng': 'papyrus maker'},
#  'chorographarius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '0',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '2',
#   'Translation_eng': 'map maker, geograph'},
#  'chorographus': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '0',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '2',
#   'Translation_eng': 'cartograph, map maker'},
#  'ciliciarius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '76',
#   'Translation_eng': 'maker of hair carpets'},
#  'circitor': {'Harris_Category': 'Managerial',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '2',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '22',
#   'Translation_eng': 'A watchman, overseer, supervisor'},
#  'circumitor': {'Harris_Category': 'Managerial',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '2',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '22',
#   'Translation_eng': 'A watchman, overseer, supervisor'},
#  'cisianus': {'Harris_Category': 'Transport',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'uncertain, the maker / driver of a cabriolet'},
#  'cisiarius': {'Harris_Category': 'Transport',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Land transport',
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'The maker / driver of a cabriolet'},
#  'citrarius': {'Harris_Category': 'Household Goods',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '81',
#   'Translation_eng': 'maker of furniture out of citrus trees'},
#  'citratius': {'Harris_Category': 'Retail',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '4',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '43',
#   'Translation_eng': 'producer and seller of citrus wood products'},
#  'claharus': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'nail maker'},
#  'clastrarius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'lock maker and seller'},
#  'claustrarius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'lock maker and seller'},
#  'clavarius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'nail maker'},
#  'clavicarius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'locksmith'},
#  'claviclarius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'A bar, bolt of the door maker, or guardian of a prison'},
#  'clavicularius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'A bar, bolt of the door maker, or guardian of a prison'},
#  'clepsydrarius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '94',
#   'Translation_eng': 'a maker of water-clocks'},
#  'clibanarius': {'Harris_Category': 'Food-Production',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'a soldier clad in mail, a cuirassier, baker'},
#  'cloacarius': {'Harris_Category': 'Water-Management',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'canal worker'},
#  'clostrarius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'lock maker and seller'},
#  'clusor': {'Harris_Category': 'Unclear meaning',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '99',
#   'Translation_eng': 'uncertain, one who encloses or encompasses'},
#  'coactarius': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '75',
#   'Translation_eng': 'felt maker'},
#  'coactiliarius': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '75',
#   'Translation_eng': 'felt maker'},
#  'coactor': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '75',
#   'Translation_eng': 'felt producer or seller'},
#  'coator': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '75',
#   'Translation_eng': 'felt producer or seller'},
#  'coctarius': {'Harris_Category': 'Food-Production',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'a cook'},
#  'coctiliarius': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'burnt brick-maker'},
#  'coctor': {'Harris_Category': 'Food-Production',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'a cook, master distiller'},
#  'coctuarius': {'Harris_Category': 'Food-Production',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'a cook'},
#  'cocus': {'Harris_Category': 'Food-Production',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'a cook '},
#  'codicarius': {'Harris_Category': 'Transport',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Maritime/water transport',
#   'HISCO_minorgroup': '98',
#   'Translation_eng': 'those who sail on such ships (esp. those who brought the corn from Ostia to Rome)'},
#  'collectiarius': {'Harris_Category': 'Finance',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '3',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '33',
#   'Translation_eng': 'money-changer'},
#  'colorator': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': 'Colour production',
#   'HISCO_minorgroup': '75',
#   'Translation_eng': 'dyer, colormaker, painter'},
#  'columnarius': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'column manufacturer'},
#  'conchylegulus': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': 'Colour production',
#   'HISCO_minorgroup': '75',
#   'Translation_eng': 'a collector of purpur shell-fish'},
#  'conchyliarius': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': 'Colour production',
#   'HISCO_minorgroup': '75',
#   'Translation_eng': 'a collector of purpur shell-fish'},
#  'conchyliolegulus': {'Harris_Category': 'Clothing',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '7',
#   'Subcategory': 'Colour production',
#   'HISCO_minorgroup': '75',
#   'Translation_eng': 'a collector of purpur shell-fish'},
#  'condeatis': {'Harris_Category': 'Transport',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '0',
#   'Subcategory': 'Maritime/water transport',
#   'HISCO_minorgroup': '4',
#   'Translation_eng': 'small boat owner'},
#  'conditarius': {'Harris_Category': 'Food-Production',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'fine cook, foor preparer'},
#  'conditor': {'Harris_Category': 'Food-Production',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'cook, a seasoner, pickler'},
#  'confector': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '76',
#   'Translation_eng': 'an accomplisher, finisher, a tanner'},
#  'confectorarius': {'Harris_Category': 'Food-Production',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'a butcher'},
#  'confectuarius': {'Harris_Category': 'Food-Production',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'a butcher'},
#  'conflator': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'a metal-caster'},
#  'conquiliarius': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': 'Colour production',
#   'HISCO_minorgroup': '75',
#   'Translation_eng': 'a collector of purpur shell-fish'},
#  'consutor': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '82',
#   'Translation_eng': 'joiner, fixer, trimmer'},
#  'copiata': {'Harris_Category': 'Death-care sector',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '59',
#   'Translation_eng': 'a grave-digger, sexton'},
#  'copo': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '51',
#   'Translation_eng': 'innkeeper'},
#  'coquus': {'Harris_Category': 'Food-Production',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'cook'},
#  'corarianus': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '76',
#   'Translation_eng': 'tanner of leather and hides'},
#  'corarius': {'Harris_Category': 'Clothing',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '76',
#   'Translation_eng': 'tanner of leather and hides'},
#  'coriarius': {'Harris_Category': 'Clothing',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '76',
#   'Translation_eng': 'a tanner, currier'},
#  'cornicen': {'Harris_Category': 'Performing Arts',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '1',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '17',
#   'Translation_eng': 'a hornblower, trumpeter, cornet-player'},
#  'cornuarius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '94',
#   'Translation_eng': 'horn maker'},
#  'coronarius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'maker of wreaths/crowns'},
#  'cotiarius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '82',
#   'Translation_eng': 'grinding stone producer, seller'},
#  'crepidarius': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': 'Shoe maker',
#   'HISCO_minorgroup': '80',
#   'Translation_eng': 'a sandal-maker, shoemaker'},
#  'cretaria': {'Harris_Category': 'Retail',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '4',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '43',
#   'Translation_eng': 'a shop for Cretan earth, pottery'},
#  'cribrarius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '94',
#   'Translation_eng': 'screen, sieve maker'},
#  'crocotarius': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': 'Colour production',
#   'HISCO_minorgroup': '75',
#   'Translation_eng': 'painter of yellow colour, dyer'},
#  'crustarius': {'Harris_Category': 'Plastic Arts',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '1',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '16',
#   'Translation_eng': 'relief maker'},
#  'crustularius': {'Harris_Category': 'Food-Production',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'one who makes pastry, a confectioner'},
#  'cucullarius': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '79',
#   'Translation_eng': 'cap / mantel maker'},
#  'culcitarius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '79',
#   'Translation_eng': 'a cushion-maker'},
#  'culinarius': {'Harris_Category': 'Food-Production',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '53',
#   'Translation_eng': 'pertaining to the kitchen, culinary, kitchen worker'},
#  'cullearius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '80',
#   'Translation_eng': 'maker of a leather bag, sack for liquids'},
# ...
#  'textrix': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '75',
#   'Translation_eng': 'female weaver'},
#  'tibiarius': {'Harris_Category': 'Transport',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Maritime/water transport',
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'fleet manufacturer, ship maker'},
#  'tibicinus': {'Harris_Category': 'Performing Arts',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '1',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '17',
#   'Translation_eng': 'flute player'},
#  'ticnarius': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Wood worker',
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'carpenter'},
#  'tignarius': {'Harris_Category': 'Building',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Wood worker',
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'carpenter'},
#  'tignuarius': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Wood worker',
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'carpenter'},
#  'tignor': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Wood worker',
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'carpenter'},
#  'tignoserrarius': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': 'Wood worker',
#   'HISCO_minorgroup': '81',
#   'Translation_eng': 'board/wood cutter'},
#  'tinctor': {'Harris_Category': 'Clothing',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '7',
#   'Subcategory': 'Colour production',
#   'HISCO_minorgroup': '75',
#   'Translation_eng': 'a dyer'},
#  'tomacularius': {'Harris_Category': 'Food-Production',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '77',
#   'Translation_eng': 'a sausage, liver-sausage maker, butcher'},
#  'tonsillaria': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '57',
#   'Translation_eng': 'female hairdresser'},
#  'tonsor': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '57',
#   'Translation_eng': 'a shearer, clipper, shaver, hair-cutter, barber'},
#  'tonstricula': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '57',
#   'Translation_eng': 'female hairdresser'},
#  'tonstrix': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '55',
#   'Translation_eng': 'female hairdresser and shearers'},
#  'topiarius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '55',
#   'Translation_eng': 'gardener, landscaper'},
#  'torcularius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '56',
#   'Translation_eng': 'a presser, pressman'},
#  'toreutes': {'Harris_Category': 'Plastic Arts',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '1',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '16',
#   'Translation_eng': 'one who makes embossed work, a chaser, graver'},
#  'toreuticesis': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'unspecified metal worker'},
#  'toreuta': {'Harris_Category': 'Plastic Arts',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '1',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '16',
#   'Translation_eng': 'one who makes embossed work, a chaser, graver'},
#  'tornator': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '99',
#   'Translation_eng': 'a turner'},
#  'tosillaria': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '57',
#   'Translation_eng': 'female hairdresser'},
#  'tosor': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '57',
#   'Translation_eng': 'hairdresser and shearers'},
#  'tostrix': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '57',
#   'Translation_eng': 'female hairdresser and shearers'},
#  'tractator': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '0',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '6',
#   'Translation_eng': "A slave among the Romans, who manipulated and suppled his master's limbs while anointing them; a shampooer"},
#  'transvectuarius': {'Harris_Category': 'Transport',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '0',
#   'Subcategory': 'Maritime/water transport',
#   'HISCO_minorgroup': '4',
#   'Translation_eng': 'ship owner'},
#  'trapezita': {'Harris_Category': 'Finance',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '3',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '33',
#   'Translation_eng': 'a money-changer'},
#  'tribor argentarius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'silver polisher'},
#  'trigalianus': {'Harris_Category': 'Unclear meaning',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '',
#   'Translation_eng': 'unclear'},
#  'triliciarius': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '79',
#   'Translation_eng': 'maker of three-thread fabric'},
#  'tubarius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': 'Military',
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'a trumpet, war-trumpet maker and distributor'},
#  'tubularius': {'Harris_Category': 'Water-Management',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '87',
#   'Translation_eng': 'pipe maker'},
#  'tudiator': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '71',
#   'Translation_eng': 'miner, ore extractor'},
#  'tussor': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '57',
#   'Translation_eng': 'hairdresser and shearers'},
#  'uctor': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '57',
#   'Translation_eng': 'an anointer'},
#  'unctor': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '57',
#   'Translation_eng': 'an anointer'},
#  'unctrix': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '57',
#   'Translation_eng': 'female perfume or ointment maker'},
#  'ungnetarius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '57',
#   'Translation_eng': 'perfume or ointment maker'},
#  'unguentarius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '57',
#   'Translation_eng': 'perfume or ointment maker'},
#  'urinator': {'Harris_Category': 'Food-Production',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '6',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '64',
#   'Translation_eng': 'a fisherman'},
#  'ursarus': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '6',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '64',
#   'Translation_eng': 'hunter of wild bears'},
#  'ustor': {'Harris_Category': 'Death-care sector',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '59',
#   'Translation_eng': 'mortician'},
#  'utriclarius': {'Harris_Category': 'Transport',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '0',
#   'Subcategory': 'Maritime/water transport',
#   'HISCO_minorgroup': '4',
#   'Translation_eng': 'a bagpiper, The master of a raft floated on bladders, used for ferriage'},
#  'utricularius': {'Harris_Category': 'Transport',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '0',
#   'Subcategory': 'Maritime/water transport',
#   'HISCO_minorgroup': '4',
#   'Translation_eng': 'a bagpiper, The master of a raft floated on bladders, used for ferriage'},
#  'valvarius': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': 'Wood worker',
#   'HISCO_minorgroup': '81',
#   'Translation_eng': 'double-door maker'},
#  'varietarius': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '0',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '2',
#   'Translation_eng': 'builder'},
#  'vasarius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'barrel smith'},
#  'vasclarius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'a worker in metals, whitesmith, goldsmith'},
#  'vascularius': {'Harris_Category': 'Metal-Working',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'a worker in metals, whitesmith, goldsmith'},
#  'vector': {'Harris_Category': 'Transport',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Land transport',
#   'HISCO_minorgroup': '97',
#   'Translation_eng': 'one who bears, a bearer, carrier'},
#  'vecturarius': {'Harris_Category': 'Transport',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '3',
#   'Subcategory': 'Land transport',
#   'HISCO_minorgroup': '36',
#   'Translation_eng': 'a driver'},
#  'vehicularius': {'Harris_Category': 'Transport',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': 'Land transport',
#   'HISCO_minorgroup': '97',
#   'Translation_eng': 'of or belonging to carriages or vehicles; post'},
#  'venator': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '6',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '64',
#   'Translation_eng': 'a hunter'},
#  'vespillo': {'Harris_Category': 'Death-care sector',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '59',
#   'Translation_eng': 'a corpse-bearer'},
#  'vestiarius': {'Harris_Category': 'Retail',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '4',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '43',
#   'Translation_eng': 'a clothes-dealer'},
#  'vestifex': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '79',
#   'Translation_eng': 'tailor'},
#  'vestificus': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '79',
#   'Translation_eng': 'tailor'},
#  'vestiplex': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '79',
#   'Translation_eng': 'a clothes-folder'},
#  'vestiplicus': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '79',
#   'Translation_eng': 'a clothes-folder'},
#  'vestitor': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '79',
#   'Translation_eng': 'tailor'},
#  'vestrix': {'Harris_Category': 'Metal-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '88',
#   'Translation_eng': 'gold weaver'},
#  'veteramentarius': {'Harris_Category': 'Building',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': 'Stone worker',
#   'HISCO_minorgroup': '95',
#   'Translation_eng': 'cobbler'},
#  'veterarius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '9',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '99',
#   'Translation_eng': 'fixer of old things'},
#  'vexillarius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '8',
#   'Subcategory': 'Military',
#   'HISCO_minorgroup': '83',
#   'Translation_eng': 'a standard-bearer, maker'},
#  'vietor': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '81',
#   'Translation_eng': 'basket weaver'},
#  'viminarius': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '81',
#   'Translation_eng': 'weaver'},
#  'vinariarius': {'Harris_Category': 'Food-Retail',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '4',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '43',
#   'Translation_eng': 'a wine - dealer'},
#  'vinarius': {'Harris_Category': 'Food-Retail',
#   'Source': 'Waltzing - provinces',
#   'HISCO_majorgroup': '4',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '43',
#   'Translation_eng': 'a wine-dealer, vintner'},
#  'violarius': {'Harris_Category': 'Clothing',
#   'Source': 'Waltzing - Rome',
#   'HISCO_majorgroup': '7',
#   'Subcategory': 'Colour production',
#   'HISCO_minorgroup': '75',
#   'Translation_eng': 'a dyer of violet color'},
#  'viridarius': {'Harris_Category': 'Miscellaneous Services',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '55',
#   'Translation_eng': 'gardener'},
#  'vispillo': {'Harris_Category': 'Death-care sector',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '5',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '59',
#   'Translation_eng': 'a corpse-bearer'},
#  'vitor': {'Harris_Category': 'Household Goods',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '81',
#   'Translation_eng': 'basket weaver'},
#  'vitrarius': {'Harris_Category': 'Glass-Working',
#   'Source': 'Petrikovits 1981b',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '89',
#   'Translation_eng': 'glass manufacturer'},
#  'vitrearius': {'Harris_Category': 'Glass-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '89',
#   'Translation_eng': 'glass manufacturer'},
#  'vitriarius': {'Harris_Category': 'Glass-Working',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '8',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '89',
#   'Translation_eng': 'glass manufacturer'},
#  'zonarius': {'Harris_Category': 'Clothing',
#   'Source': 'Petrikovits 1981a',
#   'HISCO_majorgroup': '7',
#   'Subcategory': nan,
#   'HISCO_minorgroup': '79',
#   'Translation_eng': 'belt maker'}}

# %%
for key in keys:
    occupations_counts[key] = occupations_counts["occupation"].apply(lambda x: occupation_dict[x][key])
occupations_counts.head(10)
# Out:
#      occupation  count         Harris_Category                Source  \
# 0         faber    690           Metal-Working       Waltzing - Rome
# 1       curator    340              Managerial              Waltzing
# 2       medicus    249  Miscellaneous Services       Waltzing - Rome
# 3      aerarius    235           Metal-Working       Waltzing - Rome
# 4    negotiator    130                  Retail       Waltzing - Rome
# 5   centonarius    124                Clothing       Waltzing - Rome
# 6        scriba    108               Education       Waltzing - Rome
# 7   vexillarius     75  Miscellaneous Services  Waltzing - provinces
# 8        mensor     73  Miscellaneous Services       Waltzing - Rome
# 9  dendrophorus     61                Building       Waltzing - Rome
#
#   HISCO_majorgroup  Subcategory HISCO_minorgroup  \
# 0                9          NaN               99
# 1                2          NaN               21
# 2                0          NaN                6
# 3                8          NaN               83
# 4                4          NaN               43
# 5                7          NaN               79
# 6                3          NaN               30
# 7                8     Military               83
# 8                0          NaN                2
# 9                9  Wood worker               95
#
#                                      Translation_eng                category  \
# 0  a worker in wood, stone, metal, etc., a forger...           Metal-Working
# 1  he who takes charge, a manager, overseer, supe...              Managerial
# 2                                          a surgeon  Miscellaneous Services
# 3                                       metal worker           Metal-Working
# 4  one who does business by wholesale, a wholesal...                  Retail
# 5             a maker of patchwork, a dealer in rags                Clothing
# 6  a public writer, official scribe, professional...               Education
# 7                           a standard-bearer, maker  Miscellaneous Services
# 8                               a measurer, surveyor  Miscellaneous Services
# 9                                        a carpenter                Building
#
#                                          translation
# 0  a worker in wood, stone, metal, etc., a forger...
# 1  he who takes charge, a manager, overseer, supe...
# 2                                          a surgeon
# 3                                       metal worker
# 4  one who does business by wholesale, a wholesal...
# 5             a maker of patchwork, a dealer in rags
# 6  a public writer, official scribe, professional...
# 7                           a standard-bearer, maker
# 8                               a measurer, surveyor
# 9                                        a carpenter

# %%
HISCO_majorgroup_dict = {
    "0" : "Professional, technical and related workers",
    "1" : "Professional, technical and related workers",
    "2" : "Administrative and managerial workers",
    "3" : "Clerical and related workers",
    "4" : "Sales workers",
    "5" : "Service workers",
    "6" : "Agricultural, animal husbandry and forestry workers, fishermen and hunters",
    "7" : "Production and related workers, transport equipment operators and labourers",
    "8" : "Production and related workers, transport equipment operators and labourers",
    "9" : "Production and related workers, transport equipment operators and labourers",
    "" : ""
}

# %%
occupations_counts["HISCO_majorgroup_descr"] =  occupations_counts["HISCO_majorgroup"].apply(lambda x: HISCO_majorgroup_dict[x])
occupations_counts.head(5)
# Out:
#    occupation  count         Harris_Category           Source  \
# 0       faber    690           Metal-Working  Waltzing - Rome
# 1     curator    340              Managerial         Waltzing
# 2     medicus    249  Miscellaneous Services  Waltzing - Rome
# 3    aerarius    235           Metal-Working  Waltzing - Rome
# 4  negotiator    130                  Retail  Waltzing - Rome
#
#   HISCO_majorgroup Subcategory HISCO_minorgroup  \
# 0                9         NaN               99
# 1                2         NaN               21
# 2                0         NaN                6
# 3                8         NaN               83
# 4                4         NaN               43
#
#                                      Translation_eng                category  \
# 0  a worker in wood, stone, metal, etc., a forger...           Metal-Working
# 1  he who takes charge, a manager, overseer, supe...              Managerial
# 2                                          a surgeon  Miscellaneous Services
# 3                                       metal worker           Metal-Working
# 4  one who does business by wholesale, a wholesal...                  Retail
#
#                                          translation  \
# 0  a worker in wood, stone, metal, etc., a forger...
# 1  he who takes charge, a manager, overseer, supe...
# 2                                          a surgeon
# 3                                       metal worker
# 4  one who does business by wholesale, a wholesal...
#
#                               HISCO_majorgroup_descr
# 0  Production and related workers, transport equi...
# 1              Administrative and managerial workers
# 2        Professional, technical and related workers
# 3  Production and related workers, transport equi...
# 4                                      Sales workers

# %%
occupations_counts.to_csv("../data/occupations_counts.csv")

# %% [markdown]
# ## Occupations - overview

# %%
# EDH
EDHCS[EDHCS["EDH-ID"].notnull()]["occups_N"].sum()
# Out:
# 1272

# %%
# EDCS
EDHCS[EDHCS["EDH-ID"].isnull()]["occups_N"].sum()
# Out:
# 2568

# %%
print("EDHCS - number of occupation occurances: " + str(EDHCS["occups_N"].sum()))
print("EDHCS - number of inscriptions with at least one occupation mentioned: " + str(len(EDHCS[EDHCS["occups_N"] > 0])))
# Out:
# EDHCS - number of occupation occurances: 3840
# EDHCS - number of inscriptions with at least one occupation mentioned: 3183

# %%
occupations_counts.groupby("HISCO_majorgroup_descr").sum()
# Out:
#                                                     count
# HISCO_majorgroup_descr
#                                                         3
# Administrative and managerial workers                 402
# Agricultural, animal husbandry and forestry wor...     85
# Clerical and related workers                          206
# Production and related workers, transport equip...   1902
# Professional, technical and related workers           615
# Sales workers                                         353
# Service workers                                       274

# %%
occupations_counts.groupby("HISCO_majorgroup").sum()
# Out:
#                   count
# HISCO_majorgroup
#                       3
# 0                   421
# 1                   194
# 2                   402
# 3                   206
# 4                   353
# 5                   274
# 6                    85
# 7                   317
# 8                   569
# 9                  1016

# %% [markdown]
# # Organizations - extraction

# %%
# read declined occupations
with open("../data/organizations_declined_dict.json", "r") as fp:
    orgs_declined_dict = json.load(fp)

# %%
# check that our occupations are properly arranged (from the longest...)
list(orgs_declined_dict.keys())[:15]
# Out:
# ['collegatarius',
#  'collegiarius',
#  'collegiatus',
#  'corporatus',
#  'sodalicium',
#  'collegium',
#  'collegius',
#  'concilium',
#  'conlegium',
#  'sodalitas',
#  'colegium',
#  'sociatio',
#  'societas',
#  'collega',
#  'corpus']

# %%
def extract_orgs(inscription_text):
    orgs_found = []
    if not isinstance(inscription_text, str): # if not valid string
        inscription_text = ""
    for org in orgs_declined_dict.keys():
        for orgs_morph in orgs_declined_dict[org]:
            try:
                if orgs_morph in inscription_text: # first check it this way, otherwise skip
                    orgs_morph_N = len(re.findall("(\W|^)" + orgs_morph + "(\W|$)", inscription_text))
                    orgs_found.extend([org] * orgs_morph_N)
                    inscription_text = inscription_text.replace(org_morph, "")
            except: pass
    return orgs_found

# %%
# %%time
EDHCS["organizations"] = EDHCS["clean_text_interpretive_word"].apply(extract_orgs)
# Out:
# CPU times: user 1.65 s, sys: 0 ns, total: 1.65 s
# Wall time: 1.64 s

# %%
EDHCS["organizations_N"] = EDHCS["organizations"].apply(len)

# %%
EDHCS_organizations_list = [el for sublist in EDHCS["organizations"].tolist() for el in sublist]
print(len(EDHCS_organizations_list))
print(nltk.FreqDist(EDHCS_organizations_list).most_common(30))
# Out:
# 2949
# [('collegius', 1162), ('collegium', 1152), ('corpus', 388), ('collega', 111), ('colegium', 51), ('sodalicium', 17), ('corporatus', 16), ('collegiatus', 14), ('conlegium', 13), ('societas', 12), ('concilium', 12), ('collegiarius', 1)]

# %%
organizations_counts = pd.DataFrame(nltk.FreqDist(EDHCS_organizations_list).most_common(), columns=["term", "count"])
organizations_counts
# Out:
#             term  count
# 0      collegius   1162
# 1      collegium   1152
# 2         corpus    388
# 3        collega    111
# 4       colegium     51
# 5     sodalicium     17
# 6     corporatus     16
# 7    collegiatus     14
# 8      conlegium     13
# 9       societas     12
# 10     concilium     12
# 11  collegiarius      1

# %% [markdown]
# ## Organizations - overview

# %%
# EDH
EDHCS[EDHCS["EDH-ID"].notnull()]["organizations_N"].sum()
# Out:
# 933

# %%
# EDCS
EDHCS[EDHCS["EDH-ID"].isnull()]["organizations_N"].sum()
# Out:
# 2016

# %%
organizations_counts.to_csv("../data/organizations_counts.csv")

# %%
print("EDHCS - number of organization occurances: " + str(EDHCS["organizations_N"].sum()))
print("EDHCS - number of inscriptions with at least one organization mentioned: " + str(len(EDHCS[EDHCS["organizations_N"] > 0])))
# Out:
# EDHCS - number of organization occurances: 2949
# EDHCS - number of inscriptions with at least one organization mentioned: 1242

# %%
# save locally
with open("../data/large_data/EDHCSg_occupsorgs.geojson", "w") as file: 
    json.dump(sddk.gdf_to_geojson(EDHCS), file)

# %%
s = sddk.cloudSession("sciencedata.dk", "SDAM_root", "648597@au.dk")
# Out:
# Your ScienceData username (e.g. '123456@au.dk'): 648597@au.dk
# Your ScienceData password: ········
# connection with shared folder established with you as its owner
# endpoint variable has been configured to: https://sciencedata.dk/files/SDAM_root/

# %%
s.write_file("SDAM_data/social_diversity/EDHCS_occupsorgs_2021-06-18.geojson", EDHCS)
# Out:
# Your <class 'geopandas.geodataframe.GeoDataFrame'> object has been succefully written as "https://sciencedata.dk/files/SDAM_root/SDAM_data/social_diversity/EDHCS_occupsorgs_2021-06-18.geojson"
